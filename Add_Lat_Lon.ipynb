# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime 
import seaborn as sb
import scipy.stats as stat
# %matplotlib inline
import random
from geopy.distance import vincenty

# %%
bikeshare = pd.read_csv('bikeshare_reduced.csv', 
                        parse_dates=['Start date', 'End date', 'start_date_short', 'end_date_short'])
bikeshare.drop('Unnamed: 0', 1, inplace=True)

lat_lon = pd.read_csv('bikeshare_locations.csv')
print(lat_lon.head())
# Out:
#     OBJECTID  ID                                     ADDRESS  TERMINAL_NUMBER  \
# 0  173869668   1                         Eads St & 15th St S            31000
# 1  173869669   2                             18th & Eads St.            31001
# 2  173869670   3                           20th & Crystal Dr            31002
# 3  173869671   4                           15th & Crystal Dr            31003
# 4  173869672   5  Aurora Hills Community Ctr/18th & Hayes St            31004
#
#     LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  REMOVAL_DATE  \
# 0  38.858971 -77.053230       YES     NO           NaN           NaN
# 1  38.857250 -77.053320       YES     NO           NaN           NaN
# 2  38.856425 -77.049232       YES     NO           NaN           NaN
# 3  38.860170 -77.049593       YES     NO           NaN           NaN
# 4  38.857866 -77.059490       YES     NO           NaN           NaN
#
#   TEMPORARY_INSTALL  NUMBER_OF_BIKES  NUMBER_OF_EMPTY_DOCKS            X  \
# 0                NO                0                     15  395379.9686
# 1                NO                1                     10  395372.0456
# 2                NO               12                      5  395726.8176
# 3                NO                3                      8  395695.7098
# 4                NO                4                      6  394836.5599
#
#              Y  SE_ANNO_CAD_DATA
# 0  132352.1169               NaN
# 1  132161.0781               NaN
# 2  132069.2979               NaN
# 3  132485.0368               NaN
# 4  132229.7894               NaN

# %%
lat_lon = lat_lon[['ADDRESS', 'LATITUDE', 'LONGITUDE']]

# %%
lat_lon.head()
# Out:
#                                       ADDRESS   LATITUDE  LONGITUDE
# 0                         Eads St & 15th St S  38.858971 -77.053230
# 1                             18th & Eads St.  38.857250 -77.053320
# 2                           20th & Crystal Dr  38.856425 -77.049232
# 3                           15th & Crystal Dr  38.860170 -77.049593
# 4  Aurora Hills Community Ctr/18th & Hayes St  38.857866 -77.059490

# %%
bikeshare.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:17:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                                   Start station  \
# 0                   11th & Kenyon St NW (31102)
# 1               Lamont & Mt Pleasant NW (31107)
# 2  Massachusetts Ave & Dupont Circle NW (31200)
# 3         4th St & Massachusetts Ave NW (31604)
# 4         10th St & Constitution Ave NW (31219)
#
#                                        End station Member Type  \
# 0               Calvert St & Woodley Pl NW (31106)  Registered
# 1              Adams Mill & Columbia Rd NW (31104)  Registered
# 2              Adams Mill & Columbia Rd NW (31104)      Casual
# 3           C & O Canal & Wisconsin Ave NW (31225)  Registered
# 4  14th & D St NW / Ronald Reagan Building (31231)      Casual
#
#   start_date_short end_date_short  time_diff  season  mnth  holiday  weekday  \
# 0       2011-06-30     2011-07-01       10.0       3     6        0        4
# 1       2011-06-30     2011-07-01        5.0       3     6        0        4
# 2       2011-06-30     2011-07-01       10.0       3     6        0        4
# 3       2011-06-30     2011-07-01       19.0       3     6        0        4
# 4       2011-06-30     2011-07-01       30.0       3     6        0        4
#
#    workingday  weathersit      temp     atemp       hum  windspeed
# 0           1           1  0.696667  0.637008  0.434167   0.185312
# 1           1           1  0.696667  0.637008  0.434167   0.185312
# 2           1           1  0.696667  0.637008  0.434167   0.185312
# 3           1           1  0.696667  0.637008  0.434167   0.185312
# 4           1           1  0.696667  0.637008  0.434167   0.185312

# %%
small = bikeshare.copy()

# %%
small['start_station'], small['start_station_code'] = small['Start station'].str.split("(", 1).str

# %%
small['start_station_code'] = small['start_station_code'].str.replace(')', '')

# %%
small['start_station'] = small['start_station'].str.strip()

# %%
sum(small['start_station_code'].isnull())
# Out:
# 354030

# %%
len(small['Start station'].unique())
# Out:
# 294

# %%
len(lat_lon)
# Out:
# 485

# %%
small['end_station'], small['end_station_code'] = small['End station'].str.split("(", 1).str

# %%
small['end_station_code'] = small['end_station_code'].str.replace(')', '')

# %%
small['end_station'] = small['end_station'].str.strip()

# %%
small.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:17:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                                   Start station  \
# 0                   11th & Kenyon St NW (31102)
# 1               Lamont & Mt Pleasant NW (31107)
# 2  Massachusetts Ave & Dupont Circle NW (31200)
# 3         4th St & Massachusetts Ave NW (31604)
# 4         10th St & Constitution Ave NW (31219)
#
#                                        End station Member Type  \
# 0               Calvert St & Woodley Pl NW (31106)  Registered
# 1              Adams Mill & Columbia Rd NW (31104)  Registered
# 2              Adams Mill & Columbia Rd NW (31104)      Casual
# 3           C & O Canal & Wisconsin Ave NW (31225)  Registered
# 4  14th & D St NW / Ronald Reagan Building (31231)      Casual
#
#   start_date_short end_date_short  time_diff  season  mnth       ...         \
# 0       2011-06-30     2011-07-01       10.0       3     6       ...
# 1       2011-06-30     2011-07-01        5.0       3     6       ...
# 2       2011-06-30     2011-07-01       10.0       3     6       ...
# 3       2011-06-30     2011-07-01       19.0       3     6       ...
# 4       2011-06-30     2011-07-01       30.0       3     6       ...
#
#    workingday  weathersit      temp     atemp       hum  windspeed  \
# 0           1           1  0.696667  0.637008  0.434167   0.185312
# 1           1           1  0.696667  0.637008  0.434167   0.185312
# 2           1           1  0.696667  0.637008  0.434167   0.185312
# 3           1           1  0.696667  0.637008  0.434167   0.185312
# 4           1           1  0.696667  0.637008  0.434167   0.185312
#
#                           start_station  start_station_code  \
# 0                   11th & Kenyon St NW               31102
# 1               Lamont & Mt Pleasant NW               31107
# 2  Massachusetts Ave & Dupont Circle NW               31200
# 3         4th St & Massachusetts Ave NW               31604
# 4         10th St & Constitution Ave NW               31219
#
#                                end_station end_station_code
# 0               Calvert St & Woodley Pl NW            31106
# 1              Adams Mill & Columbia Rd NW            31104
# 2              Adams Mill & Columbia Rd NW            31104
# 3           C & O Canal & Wisconsin Ave NW            31225
# 4  14th & D St NW / Ronald Reagan Building            31231
#
# [5 rows x 22 columns]

# %%
columns = list(small.columns)
columns
# Out:
# ['Start date',
#  'End date',
#  'Start station',
#  'End station',
#  'Member Type',
#  'start_date_short',
#  'end_date_short',
#  'time_diff',
#  'season',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'start_station',
#  'start_station_code',
#  'end_station',
#  'end_station_code']

# %%
list_cols = ['Start date',
 'End date',
 'start_station',
 'start_station_code',
 'end_station',
 'end_station_code',
 'Member Type',
 'start_date_short',
 'end_date_short',
 'time_diff',
 'season',
 'mnth',
 'holiday',
 'weekday',
 'workingday',
 'weathersit',
 'temp',
 'atemp',
 'hum',
 'windspeed']

# %%
small = small[list_cols]

# %%
small.shape
# Out:
# (1394542, 20)

# %%
merged_data = pd.merge(small, lat_lon, how='left', left_on='start_station', right_on='ADDRESS')

# %%
merged_data.shape
# Out:
# (1394542, 23)

# %%
merged_data.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:17:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 3         4th St & Massachusetts Ave NW              31604
# 4         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 3           C & O Canal & Wisconsin Ave NW            31225  Registered
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff    ...      weekday  workingday  \
# 0       2011-06-30     2011-07-01       10.0    ...            4           1
# 1       2011-06-30     2011-07-01        5.0    ...            4           1
# 2       2011-06-30     2011-07-01       10.0    ...            4           1
# 3       2011-06-30     2011-07-01       19.0    ...            4           1
# 4       2011-06-30     2011-07-01       30.0    ...            4           1
#
#    weathersit      temp     atemp       hum  windspeed  \
# 0           1  0.696667  0.637008  0.434167   0.185312
# 1           1  0.696667  0.637008  0.434167   0.185312
# 2           1  0.696667  0.637008  0.434167   0.185312
# 3           1  0.696667  0.637008  0.434167   0.185312
# 4           1  0.696667  0.637008  0.434167   0.185312
#
#                                 ADDRESS   LATITUDE  LONGITUDE
# 0                   11th & Kenyon St NW  38.929464 -77.027822
# 1               Lamont & Mt Pleasant NW  38.931900 -77.038800
# 2  Massachusetts Ave & Dupont Circle NW  38.910100 -77.044400
# 3                                   NaN        NaN        NaN
# 4         10th St & Constitution Ave NW  38.893028 -77.026013
#
# [5 rows x 23 columns]

# %%
merged_data = merged_data[merged_data['LATITUDE'].notnull()]

# %%
sum(merged_data['LONGITUDE'].isnull())
# Out:
# 0

# %%
merged_data = merged_data.rename(columns={'LATITUDE': 'start_lat', 'LONGITUDE': 'start_lon'})

# %%
merged_data.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
# 6 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 4         10th St & Constitution Ave NW              31219
# 6         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
# 6  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff    ...      weekday  workingday  \
# 0       2011-06-30     2011-07-01       10.0    ...            4           1
# 1       2011-06-30     2011-07-01        5.0    ...            4           1
# 2       2011-06-30     2011-07-01       10.0    ...            4           1
# 4       2011-06-30     2011-07-01       30.0    ...            4           1
# 6       2011-06-30     2011-07-01       30.0    ...            4           1
#
#    weathersit      temp     atemp       hum  windspeed  \
# 0           1  0.696667  0.637008  0.434167   0.185312
# 1           1  0.696667  0.637008  0.434167   0.185312
# 2           1  0.696667  0.637008  0.434167   0.185312
# 4           1  0.696667  0.637008  0.434167   0.185312
# 6           1  0.696667  0.637008  0.434167   0.185312
#
#                                 ADDRESS  start_lat  start_lon
# 0                   11th & Kenyon St NW  38.929464 -77.027822
# 1               Lamont & Mt Pleasant NW  38.931900 -77.038800
# 2  Massachusetts Ave & Dupont Circle NW  38.910100 -77.044400
# 4         10th St & Constitution Ave NW  38.893028 -77.026013
# 6         10th St & Constitution Ave NW  38.893028 -77.026013
#
# [5 rows x 23 columns]

# %%
full_merge = pd.merge(merged_data, lat_lon, how='left', left_on='end_station', right_on='ADDRESS')

# %%
full_merge.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:28:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 3         10th St & Constitution Ave NW              31219
# 4         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 3  14th & D St NW / Ronald Reagan Building            31231      Casual
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff    ...          temp     atemp  \
# 0       2011-06-30     2011-07-01       10.0    ...      0.696667  0.637008
# 1       2011-06-30     2011-07-01        5.0    ...      0.696667  0.637008
# 2       2011-06-30     2011-07-01       10.0    ...      0.696667  0.637008
# 3       2011-06-30     2011-07-01       30.0    ...      0.696667  0.637008
# 4       2011-06-30     2011-07-01       30.0    ...      0.696667  0.637008
#
#         hum  windspeed                             ADDRESS_x  start_lat  \
# 0  0.434167   0.185312                   11th & Kenyon St NW  38.929464
# 1  0.434167   0.185312               Lamont & Mt Pleasant NW  38.931900
# 2  0.434167   0.185312  Massachusetts Ave & Dupont Circle NW  38.910100
# 3  0.434167   0.185312         10th St & Constitution Ave NW  38.893028
# 4  0.434167   0.185312         10th St & Constitution Ave NW  38.893028
#
#    start_lon                                ADDRESS_y   LATITUDE  LONGITUDE
# 0 -77.027822               Calvert St & Woodley Pl NW  38.923583 -77.050046
# 1 -77.038800              Adams Mill & Columbia Rd NW  38.922925 -77.042581
# 2 -77.044400              Adams Mill & Columbia Rd NW  38.922925 -77.042581
# 3 -77.026013  14th & D St NW / Ronald Reagan Building  38.894514 -77.031617
# 4 -77.026013  14th & D St NW / Ronald Reagan Building  38.894514 -77.031617
#
# [5 rows x 26 columns]

# %%
sum(full_merge['LONGITUDE'].isnull())
# Out:
# 132379

# %%
full_merge = full_merge[full_merge['LATITUDE'].notnull()]

# %%
full_merge.shape
# Out:
# (1103128, 26)

# %%
full_merge = full_merge.rename(columns={'LATITUDE': 'end_lat', 'LONGITUDE': 'end_lon'})

# %%
full_merge.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:28:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 3         10th St & Constitution Ave NW              31219
# 4         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 3  14th & D St NW / Ronald Reagan Building            31231      Casual
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff    ...          temp     atemp  \
# 0       2011-06-30     2011-07-01       10.0    ...      0.696667  0.637008
# 1       2011-06-30     2011-07-01        5.0    ...      0.696667  0.637008
# 2       2011-06-30     2011-07-01       10.0    ...      0.696667  0.637008
# 3       2011-06-30     2011-07-01       30.0    ...      0.696667  0.637008
# 4       2011-06-30     2011-07-01       30.0    ...      0.696667  0.637008
#
#         hum  windspeed                             ADDRESS_x  start_lat  \
# 0  0.434167   0.185312                   11th & Kenyon St NW  38.929464
# 1  0.434167   0.185312               Lamont & Mt Pleasant NW  38.931900
# 2  0.434167   0.185312  Massachusetts Ave & Dupont Circle NW  38.910100
# 3  0.434167   0.185312         10th St & Constitution Ave NW  38.893028
# 4  0.434167   0.185312         10th St & Constitution Ave NW  38.893028
#
#    start_lon                                ADDRESS_y    end_lat    end_lon
# 0 -77.027822               Calvert St & Woodley Pl NW  38.923583 -77.050046
# 1 -77.038800              Adams Mill & Columbia Rd NW  38.922925 -77.042581
# 2 -77.044400              Adams Mill & Columbia Rd NW  38.922925 -77.042581
# 3 -77.026013  14th & D St NW / Ronald Reagan Building  38.894514 -77.031617
# 4 -77.026013  14th & D St NW / Ronald Reagan Building  38.894514 -77.031617
#
# [5 rows x 26 columns]

# %%
list(full_merge.columns)
# Out:
# ['Start date',
#  'End date',
#  'start_station',
#  'start_station_code',
#  'end_station',
#  'end_station_code',
#  'Member Type',
#  'start_date_short',
#  'end_date_short',
#  'time_diff',
#  'season',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'ADDRESS_x',
#  'start_lat',
#  'start_lon',
#  'ADDRESS_y',
#  'end_lat',
#  'end_lon']

# %%
new_list = ['Start date',
 'End date',
 'start_station',
 'start_station_code',
 'end_station',
 'end_station_code',
 'Member Type',
 'start_date_short',
 'end_date_short',
 'time_diff',
 'season',
 'mnth',
 'holiday',
 'weekday',
 'workingday',
 'weathersit',
 'temp',
 'atemp',
 'hum',
 'windspeed',
 'start_lat',
 'start_lon',
 'end_lat',
 'end_lon']

# %%
full_merge = full_merge[new_list]

# %%
full_merge['lat_lon_start'] = list(zip(full_merge.start_lat, full_merge.start_lon))

# %%
full_merge['lat_lon_end'] = list(zip(full_merge.end_lat, full_merge.end_lon))

# %%
full_merge.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:28:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 3         10th St & Constitution Ave NW              31219
# 4         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 3  14th & D St NW / Ronald Reagan Building            31231      Casual
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff           ...             \
# 0       2011-06-30     2011-07-01       10.0           ...
# 1       2011-06-30     2011-07-01        5.0           ...
# 2       2011-06-30     2011-07-01       10.0           ...
# 3       2011-06-30     2011-07-01       30.0           ...
# 4       2011-06-30     2011-07-01       30.0           ...
#
#        temp     atemp       hum  windspeed  start_lat  start_lon    end_lat  \
# 0  0.696667  0.637008  0.434167   0.185312  38.929464 -77.027822  38.923583
# 1  0.696667  0.637008  0.434167   0.185312  38.931900 -77.038800  38.922925
# 2  0.696667  0.637008  0.434167   0.185312  38.910100 -77.044400  38.922925
# 3  0.696667  0.637008  0.434167   0.185312  38.893028 -77.026013  38.894514
# 4  0.696667  0.637008  0.434167   0.185312  38.893028 -77.026013  38.894514
#
#      end_lon            lat_lon_start              lat_lon_end
# 0 -77.050046  (38.929464, -77.027822)  (38.923583, -77.050046)
# 1 -77.042581      (38.9319, -77.0388)  (38.922925, -77.042581)
# 2 -77.042581      (38.9101, -77.0444)  (38.922925, -77.042581)
# 3 -77.031617  (38.893028, -77.026013)  (38.894514, -77.031617)
# 4 -77.031617  (38.893028, -77.026013)  (38.894514, -77.031617)
#
# [5 rows x 26 columns]

# %%
full_merge['miles'] = full_merge.apply(lambda row: vincenty(row['lat_lon_start'], row['lat_lon_end']).miles, axis=1)

# %%
full_merge.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:28:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 3         10th St & Constitution Ave NW              31219
# 4         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 3  14th & D St NW / Ronald Reagan Building            31231      Casual
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff    ...        atemp       hum  \
# 0       2011-06-30     2011-07-01       10.0    ...     0.637008  0.434167
# 1       2011-06-30     2011-07-01        5.0    ...     0.637008  0.434167
# 2       2011-06-30     2011-07-01       10.0    ...     0.637008  0.434167
# 3       2011-06-30     2011-07-01       30.0    ...     0.637008  0.434167
# 4       2011-06-30     2011-07-01       30.0    ...     0.637008  0.434167
#
#    windspeed  start_lat  start_lon    end_lat    end_lon  \
# 0   0.185312  38.929464 -77.027822  38.923583 -77.050046
# 1   0.185312  38.931900 -77.038800  38.922925 -77.042581
# 2   0.185312  38.910100 -77.044400  38.922925 -77.042581
# 3   0.185312  38.893028 -77.026013  38.894514 -77.031617
# 4   0.185312  38.893028 -77.026013  38.894514 -77.031617
#
#              lat_lon_start              lat_lon_end     miles
# 0  (38.929464, -77.027822)  (38.923583, -77.050046)  1.264341
# 1      (38.9319, -77.0388)  (38.922925, -77.042581)  0.651763
# 2      (38.9101, -77.0444)  (38.922925, -77.042581)  0.890094
# 3  (38.893028, -77.026013)  (38.894514, -77.031617)  0.319015
# 4  (38.893028, -77.026013)  (38.894514, -77.031617)  0.319015
#
# [5 rows x 27 columns]

# %%
full_merge.shape
# Out:
# (1103128, 27)

# %%
full_merge.to_csv('bikeshare_lat_lon.csv')

# %%
full_merge.drop('lat_lon_start', 1, inplace=True)

# %%
full_merge.drop('lat_lon_end', 1, inplace=True)

# %%
full_merge.head()
# Out:
#            Start date            End date  \
# 0 2011-06-30 23:59:00 2011-07-01 00:09:00
# 1 2011-06-30 23:58:00 2011-07-01 00:03:00
# 2 2011-06-30 23:59:00 2011-07-01 00:09:00
# 3 2011-06-30 23:58:00 2011-07-01 00:28:00
# 4 2011-06-30 23:58:00 2011-07-01 00:28:00
#
#                           start_station start_station_code  \
# 0                   11th & Kenyon St NW              31102
# 1               Lamont & Mt Pleasant NW              31107
# 2  Massachusetts Ave & Dupont Circle NW              31200
# 3         10th St & Constitution Ave NW              31219
# 4         10th St & Constitution Ave NW              31219
#
#                                end_station end_station_code Member Type  \
# 0               Calvert St & Woodley Pl NW            31106  Registered
# 1              Adams Mill & Columbia Rd NW            31104  Registered
# 2              Adams Mill & Columbia Rd NW            31104      Casual
# 3  14th & D St NW / Ronald Reagan Building            31231      Casual
# 4  14th & D St NW / Ronald Reagan Building            31231      Casual
#
#   start_date_short end_date_short  time_diff    ...     weathersit      temp  \
# 0       2011-06-30     2011-07-01       10.0    ...              1  0.696667
# 1       2011-06-30     2011-07-01        5.0    ...              1  0.696667
# 2       2011-06-30     2011-07-01       10.0    ...              1  0.696667
# 3       2011-06-30     2011-07-01       30.0    ...              1  0.696667
# 4       2011-06-30     2011-07-01       30.0    ...              1  0.696667
#
#       atemp       hum  windspeed  start_lat  start_lon    end_lat    end_lon  \
# 0  0.637008  0.434167   0.185312  38.929464 -77.027822  38.923583 -77.050046
# 1  0.637008  0.434167   0.185312  38.931900 -77.038800  38.922925 -77.042581
# 2  0.637008  0.434167   0.185312  38.910100 -77.044400  38.922925 -77.042581
# 3  0.637008  0.434167   0.185312  38.893028 -77.026013  38.894514 -77.031617
# 4  0.637008  0.434167   0.185312  38.893028 -77.026013  38.894514 -77.031617
#
#       miles
# 0  1.264341
# 1  0.651763
# 2  0.890094
# 3  0.319015
# 4  0.319015
#
# [5 rows x 25 columns]

# %%
full_merge.to_csv('smaller_bikeshare_lat_lon.csv')

# %%
full_merge.drop('atemp', 1, inplace=True)

# %%
full_merge.to_csv('less_bikeshare_lat_lon.csv')
